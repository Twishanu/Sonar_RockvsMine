# %% [markdown]
# <a href="https://colab.research.google.com/github/Twishanu/Sonar_RockvsMine/blob/main/SonarRocksMines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing dependencies
import numpy as np
import pandas as pd
#train test split
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#Data collection and Data Processing
sonar_data = pd.read_csv('/content/sonar.csv', header=None)
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe()#count, mean... of all the columns
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar_data[60].value_counts()#60th column has R or M written
# Out:
# M    111
# R     97
# Name: 60, dtype: int64

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
#seperating data and labels
X = sonar_data.drop(columns=60, axis=1)
Y = sonar_data[60]

# %%
print(Y)
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 203    M
# 204    M
# 205    M
# 206    M
# 207    M
# Name: 60, Length: 208, dtype: object

# %%
#Training and test data
#X_train is training data X_test is testing data
#Y_train is training label Y_test is testing label
#X and Y both will be splitted
#test size represents 10% test data 90% training data
#stratify=Y --> equal number of rocks and mines in the training data
#random_state is used to order the split in a specific manner
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.1, stratify=Y, random_state=1)

# %%
print(X.shape)
# Out:
# (208, 60)

# %%
print(X_train.shape)
# Out:
# (187, 60)

# %%
print(X_test.shape)
# Out:
# (21, 60)

# %%
# training our model....Logistic Regression model will be used
model = LogisticRegression()
model.fit(X_train, Y_train)#in the graph one side is X and the other is Y
# Out:
# LogisticRegression()

# %%
#checking accuracy on training data
X_train_prediction = model.predict(X_train)#in the graph one side is X and the other is Y
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Accuracy on training data: ",training_data_accuracy)
# Out:
# Accuracy on training data:  0.8342245989304813

# %%
#checking accuracy on test data....real accuracy
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Accuracy on test data: ",test_data_accuracy)
# Out:
# Accuracy on test data:  0.7619047619047619

# %%
#Making a predictive system
input_data = (0.0047,0.0059,0.0080,0.0554,0.0883,0.1278,0.1674,0.1373,0.2922,0.3469,0.3265,0.3263,0.2301,0.1253,0.2102,0.2401,0.1928,0.1673,0.1228,0.0902,0.1557,0.3291,0.5268,0.6740,0.7906,0.8938,0.9395,0.9493,0.9040,0.9151,0.8828,0.8086,0.7180,0.6720,0.6447,0.6879,0.6241,0.4936,0.4144,0.4240,0.4546,0.4392,0.4323,0.4921,0.4710,0.3196,0.2241,0.1806,0.0990,0.0251,0.0129,0.0095,0.0126,0.0069,0.0039,0.0068,0.0060,0.0045,0.0002,0.0029
)
#changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

#reshape the numpy array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
prediction = model.predict(input_data_reshaped)#in the graph one side is X and the other is Y so when im inputting X values the prediction would be Y
print(prediction)

if (prediction[0]=='R'):
  print("It is a Rock")
else:
  print("It is a Mine")
# Out:
# ['M']
# It is a Mine

# %% [markdown]
# Hence, we can see that after training it is matching.
